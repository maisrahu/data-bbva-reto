# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from utils import *
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
pd.options.display.max_columns = 500

# %%
data_twitter = "Data/gender-classifier-DFE-791531.csv"

# %%
df_twitter = pd.read_csv(data_twitter, encoding="latin1")

# %%
df_twitter.shape
# Out:
# (20050, 26)

# %%
cols = ["_unit_id", "_last_judgment_at", "gender", "created", "description", "name", "text", "fav_number",
       "tweet_location"]

# %%
df_twitter.name.nunique()
# Out:
# 18795

# %%
df_twitter.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
#
#           created                                        description  \
# 0    12/5/13 1:48                              i sing my own rhythm.
# 1   10/1/12 13:51  I'm the author of novels filled with family dr...
# 2  11/28/14 11:30                louis whining and squealing and all
# 3   6/11/09 22:39  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4   4/16/14 13:23  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...
#
#    fav_number gender_gold link_color            name profile_yn_gold  \
# 0           0         NaN     08C2C2         sheezy0             NaN
# 1          68         NaN     0084B4     DavdBurnett             NaN
# 2        7696         NaN     ABB8C2  lwtprettylaugh             NaN
# 3         202         NaN     0084B4     douggarland             NaN
# 4       37318         NaN     3B94D9    WilfordGemma             NaN
#
#                                         profileimage  retweet_count  \
# 0  https://pbs.twimg.com/profile_images/414342229...              0
# 1  https://pbs.twimg.com/profile_images/539604221...              0
# 2  https://pbs.twimg.com/profile_images/657330418...              1
# 3  https://pbs.twimg.com/profile_images/259703936...              0
# 4  https://pbs.twimg.com/profile_images/564094871...              0
#
#   sidebar_color                                               text  \
# 0        FFFFFF  Robbie E Responds To Critics After Win Against...
# 1        C0DEED  ÛÏIt felt like they were my friends and I was...
# 2        C0DEED  i absolutely adore when louis starts the songs...
# 3        C0DEED  Hi @JordanSpieth - Looking at the url - do you...
# 4             0  Watching Neighbours on Sky+ catching up with t...
#
#   tweet_coord  tweet_count   tweet_created      tweet_id   tweet_location  \
# 0         NaN       110964  10/26/15 12:40  6.587300e+17  main; @Kan1shk3
# 1         NaN         7471  10/26/15 12:40  6.587300e+17              NaN
# 2         NaN         5617  10/26/15 12:40  6.587300e+17           clcncl
# 3         NaN         1693  10/26/15 12:40  6.587300e+17    Palo Alto, CA
# 4         NaN        31462  10/26/15 12:40  6.587300e+17              NaN
#
#                 user_timezone
# 0                     Chennai
# 1  Eastern Time (US & Canada)
# 2                    Belgrade
# 3  Pacific Time (US & Canada)
# 4                         NaN

# %%
df_twitter_sample =  df_twitter.drop_duplicates("name").reset_index(drop=True)[cols]

# %%
df_twitter_sample.head()
# Out:
#     _unit_id _last_judgment_at  gender         created  \
# 0  815719226    10/26/15 23:24    male    12/5/13 1:48
# 1  815719227    10/26/15 23:30    male   10/1/12 13:51
# 2  815719228    10/26/15 23:33    male  11/28/14 11:30
# 3  815719229    10/26/15 23:10    male   6/11/09 22:39
# 4  815719230     10/27/15 1:15  female   4/16/14 13:23
#
#                                          description            name  \
# 0                              i sing my own rhythm.         sheezy0
# 1  I'm the author of novels filled with family dr...     DavdBurnett
# 2                louis whining and squealing and all  lwtprettylaugh
# 3  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...     douggarland
# 4  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...    WilfordGemma
#
#                                                 text  fav_number  \
# 0  Robbie E Responds To Critics After Win Against...           0
# 1  ÛÏIt felt like they were my friends and I was...          68
# 2  i absolutely adore when louis starts the songs...        7696
# 3  Hi @JordanSpieth - Looking at the url - do you...         202
# 4  Watching Neighbours on Sky+ catching up with t...       37318
#
#     tweet_location
# 0  main; @Kan1shk3
# 1              NaN
# 2           clcncl
# 3    Palo Alto, CA
# 4              NaN

# %%
df_simulated = simulator.simulate(data_path="Data/", n=df_twitter_sample.shape[0])
# Out:
# C:\Users\Pedro Montenegro\BBVA_concurso

# %%
df_personas = pd.concat([df_twitter_sample, df_simulated],axis=1)

# %%
df_personas = df_personas.loc[df_personas.gender!="brand",:]

# %%
df_personas.to_csv('df_personas.csv')

# %%
df_personas.shape
# Out:
# (13375, 25)

# %%
df_personas.head()
# Out:
#     _unit_id _last_judgment_at  gender         created  \
# 0  815719226    10/26/15 23:24    male    12/5/13 1:48
# 1  815719227    10/26/15 23:30    male   10/1/12 13:51
# 2  815719228    10/26/15 23:33    male  11/28/14 11:30
# 3  815719229    10/26/15 23:10    male   6/11/09 22:39
# 4  815719230     10/27/15 1:15  female   4/16/14 13:23
#
#                                          description            name  \
# 0                              i sing my own rhythm.         sheezy0
# 1  I'm the author of novels filled with family dr...     DavdBurnett
# 2                louis whining and squealing and all  lwtprettylaugh
# 3  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...     douggarland
# 4  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...    WilfordGemma
#
#                                                 text  fav_number  \
# 0  Robbie E Responds To Critics After Win Against...           0
# 1  ÛÏIt felt like they were my friends and I was...          68
# 2  i absolutely adore when louis starts the songs...        7696
# 3  Hi @JordanSpieth - Looking at the url - do you...         202
# 4  Watching Neighbours on Sky+ catching up with t...       37318
#
#     tweet_location    dni  edad  cod_ubigeo           provincia rcc_cal_gral  \
# 0  main; @Kan1shk3  10258    47      150130               COMAS          PER
# 1              NaN  10570    37      150121          MIRAFLORES          PER
# 2           clcncl   9406    34      150901  LURIGANCHO-CHOSICA          DUD
# 3    Palo Alto, CA   5840    60      150901          LOS OLIVOS          CPP
# 4              NaN   2440    41      150102              CAÑETE          PER
#
#    rcc_num_ent_sbs  rcc_linea_tc_max  rcc_nro_prod  num_seguros_salud  \
# 0                4        561.364765             5                  1
# 1                5       1872.645033            11                  2
# 2                4       1056.139367             4                  1
# 3                1        926.663718            17                  1
# 4                2        301.570880            12                  1
#
#    ingreso_mens es_cliente flg_viaje_tw tipo_vivienda sit_laboral segmento  \
# 0    480.752552          0            0         alqui         DEP    SEGM1
# 1      0.467417          0            1         alqui         DEP    SEGM4
# 2   6343.573360          0            1         hipot         DEP    SEGM2
# 3     89.726835          0            1         hipot         DEP    SEGM2
# 4    553.573028          0            1          otro         DEP    SEGM3
#
#   prod_interes
# 0   CTA_AHORRO
# 1           TC
# 2     T_CAMBIO
# 3           TC
# 4     T_CAMBIO

# %%
df_personas["created"] = pd.to_datetime(df_personas["created"], format='%m/%d/%y %H:%M')
df_personas["_last_judgment_at"] = pd.to_datetime(df_personas["_last_judgment_at"], format='%m/%d/%y %H:%M')

# %%
df_personas["diff_lj_created"] = (df_personas["_last_judgment_at"].dt.year.astype(int)*360 + df_personas["_last_judgment_at"].dt.month.astype(int)*30).astype(int) - (df_personas["created"].dt.year.astype(int)*360 + df_personas["created"].dt.month.astype(int)*30).astype(int)   #- df_personas["created"].dt.to_period("M")

# %%
num_vars = ["flg_viaje_tw", "ingreso_mens", "num_seguros_salud", "rcc_nro_prod", "rcc_linea_tc_max", 
           "rcc_num_ent_sbs", "edad","diff_lj_created"]

# %%
def processing_num_vars(df):
    df_personas = df.copy()
    df_personas['log_ingreso_mens']=np.log(df_personas['ingreso_mens'] + 1)
    df_personas['log_num_seguros_salud']=np.log(df_personas['num_seguros_salud']+1)
    df_personas['log_rcc_nro_prod']=np.log(df_personas['rcc_nro_prod']+1)
    df_personas['log_rcc_linea_tc_max']=np.log(df_personas['rcc_linea_tc_max'] + 1)
    df_personas['log_rcc_num_ent_sbs']=np.log(df_personas['rcc_num_ent_sbs'] + 1)
    df_personas['log_edad']=np.log(df_personas['edad'] + 1)
    df_personas['log_diff_lj_created']=np.log(df_personas['diff_lj_created'] + 1)

    return df_personas

# %%
df_personas.head(1)
# Out:
#     _unit_id   _last_judgment_at gender             created  \
# 0  815719226 2015-10-26 23:24:00   male 2013-12-05 01:48:00
#
#              description     name  \
# 0  i sing my own rhythm.  sheezy0
#
#                                                 text  fav_number  \
# 0  Robbie E Responds To Critics After Win Against...           0
#
#     tweet_location    dni  edad  cod_ubigeo provincia rcc_cal_gral  \
# 0  main; @Kan1shk3  10258    47      150130     COMAS          PER
#
#    rcc_num_ent_sbs  rcc_linea_tc_max  rcc_nro_prod  num_seguros_salud  \
# 0                4        561.364765             5                  1
#
#    ingreso_mens es_cliente flg_viaje_tw tipo_vivienda sit_laboral segmento  \
# 0    480.752552          0            0         alqui         DEP    SEGM1
#
#   prod_interes  diff_lj_created
# 0   CTA_AHORRO              660

# %%
df_personas.sit_laboral.value_counts()
# Out:
# DEP      7985
# INDEP    5390
# Name: sit_laboral, dtype: int64

# %%
df_personas.tipo_vivienda.value_counts()
# Out:
# alqui     5414
# hipot     4004
# propia    1329
# otro      1327
# fami      1301
# Name: tipo_vivienda, dtype: int64

# %%
def get_nse(serie):
    
    #print(serie)
    
    if (serie["sit_laboral"] == "DEP") and (serie["tipo_vivienda"] in ["propia"]):
        return "A"
    elif (serie["sit_laboral"] == "DEP") and (serie["tipo_vivienda"] in ["fami", "hipot"]):
        return "B"
    elif (serie["sit_laboral"] == "DEP") and (serie["tipo_vivienda"] in ["fami", "alqui"]):
        return "C"
    else: 
        return "D"

# %%
df_personas["nse"] = df_personas.apply(get_nse, axis=1)

# %%
cat_vars = ["gender", "provincia", "rcc_cal_gral", "nse", "segmento"]

# %%
def processing_cat_vars(df):
    df_personas = df.copy()
    
    df_personas.loc[df_personas.rcc_cal_gral=='OK','enc_rcc_cal_gral']=5
    df_personas.loc[df_personas.rcc_cal_gral=='CPP','enc_rcc_cal_gral']=4
    df_personas.loc[df_personas.rcc_cal_gral=='DEF','enc_rcc_cal_gral']=3
    df_personas.loc[df_personas.rcc_cal_gral=='DUD','enc_rcc_cal_gral']=2
    df_personas.loc[df_personas.rcc_cal_gral=='PER','enc_rcc_cal_gral']=1
    df_personas.loc[df_personas.rcc_cal_gral=='OTR','enc_rcc_cal_gral']=0
    
    df_personas.loc[df_personas.nse=='A','enc_nse']=4
    df_personas.loc[df_personas.nse=='B','enc_nse']=3
    df_personas.loc[df_personas.nse=='C','enc_nse']=2
    df_personas.loc[df_personas.nse=='D','enc_nse']=1
    df_personas.loc[df_personas.nse=='E','enc_nse']=0
    
    df_personas.loc[df_personas.segmento=='SEGM4','enc_segmento']=3
    df_personas.loc[df_personas.segmento=='SEGM3','enc_segmento']=2
    df_personas.loc[df_personas.segmento=='SEGM2','enc_segmento']=1
    df_personas.loc[df_personas.segmento=='SEGM1','enc_segmento']=0

    
    df_personas['enc_gender'] = df_personas['gender'].map(df_personas['gender'].value_counts()/len(df_personas))
    df_personas['enc_provincia'] = df_personas['provincia'].map(df_personas['provincia'].value_counts()/len(df_personas))
    
    le=LabelEncoder()
    df_personas['le_provincia']=le.fit_transform(df_personas['provincia'])
    
    return df_personas

# %%
cols_yes = ["log_ingreso_mens", "log_num_seguros_salud", "log_rcc_nro_prod", "log_rcc_linea_tc_max", 
            "log_rcc_num_ent_sbs", "log_edad", "log_diff_lj_created","enc_rcc_cal_gral",
            "enc_nse", "enc_segmento", "enc_gender"]
num_vars + cat_vars
# Out:
# ['flg_viaje_tw',
#  'ingreso_mens',
#  'num_seguros_salud',
#  'rcc_nro_prod',
#  'rcc_linea_tc_max',
#  'rcc_num_ent_sbs',
#  'edad',
#  'diff_lj_created',
#  'gender',
#  'provincia',
#  'rcc_cal_gral',
#  'nse',
#  'segmento']

# %%
df_personas = df_personas.dropna()

# %%
df_personas = processing_cat_vars(df_personas)

df_personas = processing_num_vars(df_personas)

# %%
df_personas[cols_yes].head()
# Out:
#    log_ingreso_mens  log_num_seguros_salud  log_rcc_nro_prod  \
# 0          6.177431               0.693147          1.791759
# 2          8.755355               0.693147          1.609438
# 3          4.507853               0.693147          2.890372
# 5          5.266749               0.693147          2.079442
# 9          6.682546               1.098612          2.639057
#
#    log_rcc_linea_tc_max  log_rcc_num_ent_sbs  log_edad  log_diff_lj_created  \
# 0              6.332151             1.609438  3.871201             6.493754
# 2              6.963322             1.609438  3.555348             5.802118
# 3              6.832669             0.693147  4.110874             7.732369
# 5              6.827518             0.693147  4.248495             7.606387
# 9              4.827033             2.197225  3.526361             7.372118
#
#    enc_rcc_cal_gral  enc_nse  enc_segmento  enc_gender  le_provincia
# 0               1.0      2.0           0.0    0.489182            12
# 2               2.0      3.0           1.0    0.489182            24
# 3               4.0      3.0           1.0    0.489182            23
# 5               4.0      2.0           1.0    0.457875            51
# 9               2.0      2.0           2.0    0.457875            38

# %%
df_personas[cols_yes].dtypes
# Out:
# log_ingreso_mens         float64
# log_num_seguros_salud    float64
# log_rcc_nro_prod         float64
# log_rcc_linea_tc_max     float64
# log_rcc_num_ent_sbs      float64
# log_edad                 float64
# log_diff_lj_created      float64
# enc_rcc_cal_gral         float64
# enc_nse                  float64
# enc_segmento             float64
# enc_gender               float64
# le_provincia               int32
# dtype: object

# %%
df_personas[cols_yes].dropna()
# Out:
#        log_ingreso_mens  log_num_seguros_salud  log_rcc_nro_prod  \
# 0              6.177431               0.693147          1.791759
# 2              8.755355               0.693147          1.609438
# 3              4.507853               0.693147          2.890372
# 5              5.266749               0.693147          2.079442
# 9              6.682546               1.098612          2.639057
# ...                 ...                    ...               ...
# 18785          7.801203               0.693147          2.890372
# 18788          5.746432               1.098612          2.302585
# 18789          7.121282               0.693147          2.302585
# 18790          5.155751               0.693147          1.791759
# 18792          6.686165               0.693147          2.197225
#
#        log_rcc_linea_tc_max  log_rcc_num_ent_sbs  log_edad  \
# 0                  6.332151             1.609438  3.871201
# 2                  6.963322             1.609438  3.555348
# 3                  6.832669             0.693147  4.110874
# 5                  6.827518             0.693147  4.248495
# 9                  4.827033             2.197225  3.526361
# ...                     ...                  ...       ...
# 18785              5.838163             2.079442  3.610918
# 18788              6.918369             1.609438  3.401197
# 18789              6.934233             2.079442  3.988984
# 18790              5.058213             1.098612  4.204693
# 18792              6.123053             1.791759  4.094345
#
#        log_diff_lj_created  enc_rcc_cal_gral  enc_nse  enc_segmento  \
# 0                 6.493754               1.0      2.0           0.0
# 2                 5.802118               2.0      3.0           1.0
# 3                 7.732369               4.0      3.0           1.0
# 5                 7.606387               4.0      2.0           1.0
# 9                 7.372118               2.0      2.0           2.0
# ...                    ...               ...      ...           ...
# 18785             7.528869               5.0      1.0           1.0
# 18788             7.528869               5.0      3.0           3.0
# 18789             7.719130               1.0      3.0           2.0
# 18790             6.898715               4.0      4.0           1.0
# 18792             5.198497               1.0      1.0           1.0
#
#        enc_gender
# 0        0.489182
# 2        0.489182
# 3        0.489182
# 5        0.457875
# 9        0.457875
# ...           ...
# 18785    0.457875
# 18788    0.489182
# 18789    0.457875
# 18790    0.489182
# 18792    0.457875
#
# [8273 rows x 11 columns]

# %% [markdown]
# ## Clustering

# %%
# Librerías
#Algoritmo
from sklearn.cluster import KMeans

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_personas_md = df_personas[cols_yes].dropna()

# %%
def elbowMethod(datos, max_clusters = 10, iterat = 200):

    wcss = []

    for i in range(1, max_clusters):

        kmeans = KMeans(n_clusters = i, init = "k-means++", max_iter=iterat, n_init=10, random_state=123)
        kmeans.fit(datos)

        wcss.append(kmeans.inertia_)

    plt.plot(range(1, max_clusters), wcss)
    plt.title("Método del codo")
    plt.xlabel("Cantidad de clusters")
    plt.ylabel("WCSS(k)")
    plt.show()

# %%
elbowMethod(df_personas_md)

# %%
# Config modelo
Kmeans = KMeans(n_clusters=5, random_state=123).fit(df_personas_md)

# %%
# Predecimos el grupo
y_pred = Kmeans.predict(df_personas_md)

# %%
y_pred
# Out:
# array([1, 1, 3, ..., 1, 4, 1])

# %%
labels = y_pred

# %% [markdown]
# Para visualizar bien, usemos PCA y miremos la distribución de los datos por clasificación real y por clasificación inferida:

# %%
'''from sklearn.decomposition import PCA

# Se usa PCA para reducir dimensiones de 64 a solo 2
X = PCA(2).fit_transform(df_personas_md)

kwargs = dict(cmap = plt.cm.get_cmap('rainbow', 10), edgecolor='none', alpha=0.6, s=100)

fig, ax = plt.subplots(1, 2, figsize=(12, 6));

ax[1].set_title('Clasificación Aprendida');
ax[1].axis('off');
ax[1].scatter(X[:, 0], X[:, 1], c=labels, **kwargs);'''

# %%
# Asignar valores como target
df_personas_md['Target'] = y_pred

# %%
df_personas_md.groupby('Target').mean()
# Out:
#         log_ingreso_mens  log_num_seguros_salud  log_rcc_nro_prod  \
# Target
# 0               6.987345               0.790542          2.198070
# 1               6.947456               0.794606          2.199355
# 2               4.648630               0.797480          2.178244
# 3               4.816919               0.792041          2.192284
# 4               6.711756               0.798516          2.191862
#
#         log_rcc_linea_tc_max  log_rcc_num_ent_sbs  log_edad  \
# Target
# 0                   6.915710             1.544711  3.719594
# 1                   6.944699             1.582445  3.731507
# 2                   6.559995             1.580200  3.734043
# 3                   6.626001             1.550745  3.716931
# 4                   4.627570             1.564462  3.733105
#
#         log_diff_lj_created  enc_rcc_cal_gral   enc_nse  enc_segmento  \
# Target
# 0                  7.061848          3.996269  1.899720      1.684701
# 1                  6.695098          1.238854  1.900819      1.737944
# 2                  7.092479          1.224016  1.930373      1.619576
# 3                  6.597552          4.015009  1.878987      1.811445
# 4                  6.872324          2.503735  1.871398      1.692102
#
#         enc_gender
# Target
# 0         0.453697
# 1         0.449702
# 2         0.454055
# 3         0.452166
# 4         0.450474

# %%
df_personas_md.shape
# Out:
# (8273, 12)

# %%
#Cluster 0: # Perfil inversor, mayores ingresos, perfil de más consumo
#Fondos mutuos

#Cluster 1: Percibe ingresos altos, probable moroso
#Adelanto de sueldo
#Depósito a plazo

#Cluster 2: # probable moroso, problable que se endeude
#Ctas de Ahorro
#T_cambio

#Cluster 3: # Buen pagador, perfil de consumo
#Tarjeta de crédito

#Cluster 4: Percibe ingreso promedio, requiere de dinero inmediato
#Préstamo al toque

# %%
df_final['target']= y_pred

# %%
df_final = df_personas.dropna()
df_final['target']= y_pred

# %%
df_final.head()
# Out:
#     _unit_id   _last_judgment_at  gender             created  \
# 0  815719226 2015-10-26 23:24:00    male 2013-12-05 01:48:00
# 2  815719228 2015-10-26 23:33:00    male 2014-11-28 11:30:00
# 3  815719229 2015-10-26 23:10:00    male 2009-06-11 22:39:00
# 5  815719231 2015-10-27 01:47:00  female 2010-03-11 18:14:00
# 9  815719235 2015-10-27 01:49:00  female 2011-05-13 03:32:00
#
#                                          description            name  \
# 0                              i sing my own rhythm.         sheezy0
# 2                louis whining and squealing and all  lwtprettylaugh
# 3  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...     douggarland
# 5                                 you don't know me.   monroevicious
# 9  Renaissance art historian, University of Notti...   GabrieleNeher
#
#                                                 text  fav_number  \
# 0  Robbie E Responds To Critics After Win Against...           0
# 2  i absolutely adore when louis starts the songs...        7696
# 3  Hi @JordanSpieth - Looking at the url - do you...         202
# 5  Ive seen people on the train with lamps, chair...        3901
# 9  @Evielady just how lovely is the tree this yea...        3115
#
#          tweet_location    dni  edad  cod_ubigeo           provincia  \
# 0       main; @Kan1shk3  10258    47      150130               COMAS
# 2                clcncl   9406    34      150901  LURIGANCHO-CHOSICA
# 3         Palo Alto, CA   5840    60      150901          LOS OLIVOS
# 5       New York Gritty  11400    69      150401              YAUYOS
# 9  Nottingham, England.   4789    33      150143          SAN ISIDRO
#
#   rcc_cal_gral  rcc_num_ent_sbs  rcc_linea_tc_max  rcc_nro_prod  \
# 0          PER                4        561.364765             5
# 2          DUD                4       1056.139367             4
# 3          CPP                1        926.663718            17
# 5          CPP                1        921.897481             7
# 9          DUD                8        123.840063            13
#
#    num_seguros_salud  ingreso_mens es_cliente flg_viaje_tw tipo_vivienda  \
# 0                  1    480.752552          0            0         alqui
# 2                  1   6343.573360          0            1         hipot
# 3                  1     89.726835          0            1         hipot
# 5                  1    192.784978          0            0         alqui
# 9                  2    797.348955          0            0         alqui
#
#   sit_laboral segmento prod_interes  diff_lj_created nse  enc_rcc_cal_gral  \
# 0         DEP    SEGM1   CTA_AHORRO              660   C               1.0
# 2         DEP    SEGM2     T_CAMBIO              330   B               2.0
# 3         DEP    SEGM2           TC             2280   B               4.0
# 5         DEP    SEGM2           DP             2010   C               4.0
# 9         DEP    SEGM3   CTA_AHORRO             1590   C               2.0
#
#    enc_nse  enc_segmento  enc_gender  enc_provincia  le_provincia  \
# 0      2.0           0.0    0.489182       0.018494            12
# 2      3.0           1.0    0.489182       0.017285            24
# 3      3.0           1.0    0.489182       0.017648            23
# 5      2.0           1.0    0.457875       0.020186            51
# 9      2.0           2.0    0.457875       0.018615            38
#
#    log_ingreso_mens  log_num_seguros_salud  log_rcc_nro_prod  \
# 0          6.177431               0.693147          1.791759
# 2          8.755355               0.693147          1.609438
# 3          4.507853               0.693147          2.890372
# 5          5.266749               0.693147          2.079442
# 9          6.682546               1.098612          2.639057
#
#    log_rcc_linea_tc_max  log_rcc_num_ent_sbs  log_edad  log_diff_lj_created  \
# 0              6.332151             1.609438  3.871201             6.493754
# 2              6.963322             1.609438  3.555348             5.802118
# 3              6.832669             0.693147  4.110874             7.732369
# 5              6.827518             0.693147  4.248495             7.606387
# 9              4.827033             2.197225  3.526361             7.372118
#
#    target
# 0       1
# 2       1
# 3       3
# 5       3
# 9       4

# %%
df_final.target.value_counts()
# Out:
# 1    2198
# 0    2144
# 4    1874
# 3    1066
# 2     991
# Name: target, dtype: int64

# %%
df_final.to_csv("df_final_target.csv")

# %%
#cols_yes.append('target')
df_final[cols_yes]
# Out:
#        log_ingreso_mens  log_num_seguros_salud  log_rcc_nro_prod  \
# 0              6.177431               0.693147          1.791759
# 2              8.755355               0.693147          1.609438
# 3              4.507853               0.693147          2.890372
# 5              5.266749               0.693147          2.079442
# 9              6.682546               1.098612          2.639057
# ...                 ...                    ...               ...
# 18785          7.801203               0.693147          2.890372
# 18788          5.746432               1.098612          2.302585
# 18789          7.121282               0.693147          2.302585
# 18790          5.155751               0.693147          1.791759
# 18792          6.686165               0.693147          2.197225
#
#        log_rcc_linea_tc_max  log_rcc_num_ent_sbs  log_edad  \
# 0                  6.332151             1.609438  3.871201
# 2                  6.963322             1.609438  3.555348
# 3                  6.832669             0.693147  4.110874
# 5                  6.827518             0.693147  4.248495
# 9                  4.827033             2.197225  3.526361
# ...                     ...                  ...       ...
# 18785              5.838163             2.079442  3.610918
# 18788              6.918369             1.609438  3.401197
# 18789              6.934233             2.079442  3.988984
# 18790              5.058213             1.098612  4.204693
# 18792              6.123053             1.791759  4.094345
#
#        log_diff_lj_created  enc_rcc_cal_gral  enc_nse  enc_segmento  \
# 0                 6.493754               1.0      2.0           0.0
# 2                 5.802118               2.0      3.0           1.0
# 3                 7.732369               4.0      3.0           1.0
# 5                 7.606387               4.0      2.0           1.0
# 9                 7.372118               2.0      2.0           2.0
# ...                    ...               ...      ...           ...
# 18785             7.528869               5.0      1.0           1.0
# 18788             7.528869               5.0      3.0           3.0
# 18789             7.719130               1.0      3.0           2.0
# 18790             6.898715               4.0      4.0           1.0
# 18792             5.198497               1.0      1.0           1.0
#
#        enc_gender
# 0        0.489182
# 2        0.489182
# 3        0.489182
# 5        0.457875
# 9        0.457875
# ...           ...
# 18785    0.457875
# 18788    0.489182
# 18789    0.457875
# 18790    0.489182
# 18792    0.457875
#
# [8273 rows x 11 columns]

# %% [markdown]
# ## Entrenamiento LightGBM

# %%
# %matplotlib inline

#Algoritmos
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb


from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn import datasets

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd

# %%
X = df_final[cols_yes]
Y = df_final['target']

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.3, random_state = 10)

# %%
# Default model
base_model =lgb.LGBMClassifier(objective='multiclass',random_state=420)
base_model.fit(X_train, Y_train)
# Out:
# LGBMClassifier(objective='multiclass', random_state=420)

# %%
scores2 = base_model.predict(X_test)

# %%
print(accuracy_score(Y_test,scores2))
# Out:
# 0.9818694601128123

# %% [markdown]
# ### Hiperparámetros

# %%
lg = lgb.LGBMClassifier(silent=False) #importamos el clasificador, silent = False
cate_features_name = ["cat1","cat2","cat3"] # nombres categoricas
param_dist = {"max_depth": [3,6,9], #en esta lista, haremos la grilla de hyperparametros que deseamos tunear
              "learning_rate" : [0.05,0.1], 
              "boosting": ["goss","gbdt"],
              "min_data_in_leaf": [5,10,20], 'objective': ['multiclass'],
              'num_class':[3],
               "n_estimators" : [50,100,200],
              "n_leaves" : [6,52,300]
             }

grid_search = GridSearchCV(lg, n_jobs=-1, param_grid=param_dist, cv = 10, scoring="accuracy", verbose=5) # gridsearch con cross validation de 3, = 3*(parámetros^cantidad de elementos en cada paraemtros que deseesmo buscar.)
grid_search.fit(X_train,Y_train) # inicia la creacion de modelos
grid_search.best_estimator_
# Out:
# Fitting 10 folds for each of 324 candidates, totalling 3240 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:   38.1s
# [Parallel(n_jobs=-1)]: Done 858 tasks      | elapsed:   54.2s
# [Parallel(n_jobs=-1)]: Done 1128 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 1776 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 2154 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 2568 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 3018 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 3240 out of 3240 | elapsed:  3.3min finished
# [LightGBM] [Warning] Unknown parameter: n_leaves
# [LightGBM] [Warning] boosting is set=goss, boosting_type=gbdt will be ignored. Current value: boosting=goss
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: n_leaves
# [LightGBM] [Warning] boosting is set=goss, boosting_type=gbdt will be ignored. Current value: boosting=goss
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000251 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 725
# [LightGBM] [Info] Number of data points in the train set: 5791, number of used features: 11
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] Start training from score -1.348842
# [LightGBM] [Info] Start training from score -1.332345
# [LightGBM] [Info] Start training from score -2.120148
# [LightGBM] [Info] Start training from score -2.021573
# [LightGBM] [Info] Start training from score -1.495480
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMClassifier(boosting='goss', learning_rate=0.05, max_depth=9,
#                min_data_in_leaf=5, n_estimators=200, n_leaves=6, num_class=3,
#                objective='multiclass', silent=False)

# %%
grid_search.best_params_
# Out:
# {'boosting': 'goss',
#  'learning_rate': 0.05,
#  'max_depth': 9,
#  'min_data_in_leaf': 5,
#  'n_estimators': 200,
#  'n_leaves': 6,
#  'num_class': 3,
#  'objective': 'multiclass'}

# %%
grid_search.best_score_
# Out:
# 0.9832493597760704

# %%
best_paramas = grid_search.best_params_

# %%
model = lgb.LGBMClassifier(boosting_type='goss',num_leaves=6,learning_rate=0.1,max_depth=3,n_estimators=200,objective='multiclass',random_state=420)
model.fit(X_train, Y_train)
# Out:
# LGBMClassifier(boosting_type='goss', max_depth=3, n_estimators=200,
#                num_leaves=6, objective='multiclass', random_state=420)

# %%
scores = model.predict(X_test)

# %%
print(accuracy_score(Y_test,scores))
# Out:
# 0.9834810636583401

# %%
import pickle

# %%
# guardar modelo
filename = 'lightgbm_pred.pk'
pickle.dump(model, open(filename, 'wb'))

# %%
# predecir con modelo
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, Y_test)
pred = loaded_model.predict(X_test)
print(result)
# Out:
# 0.9834810636583401

# %%
pred
# Out:
# array([1, 0, 2, ..., 4, 4, 3])

# %%
# guardar modelo
filename = 'kmeans.pk'
pickle.dump(Kmeans, open(filename, 'wb'))

# %%
# predecir con modelo
loaded_model = pickle.load(open(filename, 'rb'))
#result = loaded_model.score(X_test, Y_test)
pred = loaded_model.predict(X_test)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-244-7b902f59cd01> in <module>
#       2 loaded_model = pickle.load(open(filename, 'rb'))
#       3 #result = loaded_model.score(X_test, Y_test)
# ----> 4 pred = loaded_model.predict(X_test)
#       5 print(result)
#
# D:\Anaconda3_updt\lib\site-packages\sklearn\cluster\_kmeans.py in predict(self, X, sample_weight)
#    1199         check_is_fitted(self)
#    1200
# -> 1201         X = self._check_test_data(X)
#    1202         x_squared_norms = row_norms(X, squared=True)
#    1203
#
# D:\Anaconda3_updt\lib\site-packages\sklearn\cluster\_kmeans.py in _check_test_data(self, X)
#     996         expected_n_features = self.cluster_centers_.shape[1]
#     997         if not n_features == expected_n_features:
# --> 998             raise ValueError(
#     999                 f"Incorrect number of features. Got {n_features} features, "
#    1000                 f"expected {expected_n_features}.")
#
# ValueError: Incorrect number of features. Got 11 features, expected 12.

# %%
df_plot = df_final[cols_yes]
df_plot['target'] = df_final['target']
#df_plot
# Out:
# <ipython-input-246-d8e539d77ff3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['target'] = df_final['target']

# %%
sns.pairplot(df_plot, hue="target")#, markers=["o", "s", "D","p","e"])

# %%
sns.pairplot(df_plot.loc[:,['log_ingreso_mens','log_edad','target']], hue="target")#, markers=["o", "s", "D","p","e"])

# %%
sns.pairplot(df_plot.loc[:,['log_ingreso_mens','log_rcc_linea_tc_max','target']], hue="target")#, markers=["o", "s", "D","p","e"])

# %%
sns.pairplot(df_plot.loc[:,['log_edad','log_rcc_linea_tc_max','target']], hue="target")

# %%
sns.pairplot(df_plot.loc[:,['log_diff_lj_created','log_rcc_linea_tc_max','target']], hue="target")

# %%
df_plot
# Out:
#        log_ingreso_mens  log_num_seguros_salud  log_rcc_nro_prod  \
# 0              6.177431               0.693147          1.791759
# 2              8.755355               0.693147          1.609438
# 3              4.507853               0.693147          2.890372
# 5              5.266749               0.693147          2.079442
# 9              6.682546               1.098612          2.639057
# ...                 ...                    ...               ...
# 18785          7.801203               0.693147          2.890372
# 18788          5.746432               1.098612          2.302585
# 18789          7.121282               0.693147          2.302585
# 18790          5.155751               0.693147          1.791759
# 18792          6.686165               0.693147          2.197225
#
#        log_rcc_linea_tc_max  log_rcc_num_ent_sbs  log_edad  \
# 0                  6.332151             1.609438  3.871201
# 2                  6.963322             1.609438  3.555348
# 3                  6.832669             0.693147  4.110874
# 5                  6.827518             0.693147  4.248495
# 9                  4.827033             2.197225  3.526361
# ...                     ...                  ...       ...
# 18785              5.838163             2.079442  3.610918
# 18788              6.918369             1.609438  3.401197
# 18789              6.934233             2.079442  3.988984
# 18790              5.058213             1.098612  4.204693
# 18792              6.123053             1.791759  4.094345
#
#        log_diff_lj_created  enc_rcc_cal_gral  enc_nse  enc_segmento  \
# 0                 6.493754               1.0      2.0           0.0
# 2                 5.802118               2.0      3.0           1.0
# 3                 7.732369               4.0      3.0           1.0
# 5                 7.606387               4.0      2.0           1.0
# 9                 7.372118               2.0      2.0           2.0
# ...                    ...               ...      ...           ...
# 18785             7.528869               5.0      1.0           1.0
# 18788             7.528869               5.0      3.0           3.0
# 18789             7.719130               1.0      3.0           2.0
# 18790             6.898715               4.0      4.0           1.0
# 18792             5.198497               1.0      1.0           1.0
#
#        enc_gender  target
# 0        0.489182       1
# 2        0.489182       1
# 3        0.489182       3
# 5        0.457875       3
# 9        0.457875       4
# ...           ...     ...
# 18785    0.457875       0
# 18788    0.489182       3
# 18789    0.457875       1
# 18790    0.489182       4
# 18792    0.457875       1
#
# [8273 rows x 12 columns]
